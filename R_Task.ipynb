# %% [markdown]
# <a href="https://colab.research.google.com/github/lailasaummi/Tasks-Virtual-Intership-id-x-partners/blob/main/R_Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 3 QUESTION NUMBER 11**

# %%
# Import ggplot2 library to visualize using chart
library(ggplot2)

# %%
# Plot data in Scatter Chart
ggplot(mpg, aes(x = displ, y = hwy, color = class)) + geom_point()
# Out:
# plot without title
